# %%
import numpy as np

import statsmodels.api as sm

import statsmodels.formula.api as smf
# Out:
# C:\Users\QUYEN\Anaconda2\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import pandas as pd

# %%
cd E:\HK6\Phân tích dữ liệu kinh doanh\BaiTap\BaiTapLap04\BaoCao
# Out:
# E:\HK6\Phân tích dữ liệu kinh doanh\BaiTap\BaiTapLap04\BaoCao

# %%
pwd
# Out:
# u'E:\\HK6\\Ph\xe2n t\xedch d\u1eef li\u1ec7u kinh doanh\\BaiTap\\BaiTapLap04\\BaoCao'

# %%
pd.read_csv('Home Market Value.csv')
# Out:
#     House Age  Square Feet  Market Value
# 0          33         1812         90000
# 1          32         1914        104400
# 2          32         1842         93300
# 3          33         1812         91000
# 4          32         1836        101900
# 5          33         2028        108500
# 6          32         1732         87600
# 7          33         1850         96000
# 8          32         1791         89200
# 9          33         1666         88400
# 10         32         1852        100800
# 11         32         1620         96700
# 12         32         1692         87500
# 13         32         2372        114000
# 14         32         2372        113200
# 15         33         1666         87500
# 16         32         2123        116100
# 17         32         1620         94700
# 18         32         1731         86400
# 19         32         1666         87100
# 20         28         1520         83400
# 21         27         1484         79800
# ...

# %%
x=pd.read_csv('Home Market Value.csv')
x.head()
# Out:
#    House Age  Square Feet  Market Value
# 0         33         1812         90000
# 1         32         1914        104400
# 2         32         1842         93300
# 3         33         1812         91000
# 4         32         1836        101900

# %%
cyl=x['Square Feet']

# %%
cyl
# Out:
# 0     1812
# 1     1914
# 2     1842
# 3     1812
# 4     1836
# 5     2028
# 6     1732
# 7     1850
# 8     1791
# 9     1666
# 10    1852
# 11    1620
# 12    1692
# 13    2372
# 14    2372
# 15    1666
# 16    2123
# 17    1620
# 18    1731
# 19    1666
# 20    1520
# 21    1484
# 22    1588
# 23    1598
# 24    1484
# 25    1484
# 26    1520
# 27    1701
# 28    1484
# 29    1468
# 30    1520
# 31    1520
# 32    1484
# 33    1520
# 34    1668
# 35    1588
# 36    1784
# 37    1484
# 38    1520
# 39    1520
# 40    1684
# 41    1581
# Name: Square Feet, dtype: int64

# %%
import statsmodels.api as sm # import statsmodels 

X = x["Square Feet"] ## X usually means our input variables (or independent variables)
y = x["Market Value"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)
predictions = model.predict(X)

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           Market Value   R-squared:                       0.535
# Model:                            OLS   Adj. R-squared:                  0.523
# Method:                 Least Squares   F-statistic:                     45.97
# Date:                Sat, 19 May 2018   Prob (F-statistic):           3.80e-08
# Time:                        20:05:45   Log-Likelihood:                -432.12
# No. Observations:                  42   AIC:                             868.2
# Df Residuals:                      40   BIC:                             871.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        3.267e+04   8831.951      3.699      0.001    1.48e+04    5.05e+04
# ...
