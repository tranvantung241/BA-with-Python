# %% [raw]
# # Statistical Forecasting Models

# %%
import warnings; warnings.simplefilter("ignore")

# %matplotlib inline
import matplotlib.pyplot as pl
import seaborn as sns
import numpy as np
import pandas as pd

# %%
TabCompSales= pd.ExcelFile("D:/OneDrive/UIT HK6/BA/Slide English/UIT_Slide_BA/Lab/Data Files for Business Analytics/Tablet Computer Sales.xlsx")

sheet1 = pd.read_excel(r"D:/OneDrive/UIT HK6/BA/Slide English/UIT_Slide_BA/Lab/Data Files for Business Analytics/Tablet Computer Sales.xlsx", sheetname=0)

sheet1.plot()

# %%
pd.rolling_mean(sheet1["Units Sold"],3)
# Out:
# 0           NaN
# 1           NaN
# 2     64.000000
# 3     53.333333
# 4     62.000000
# 5     72.333333
# 6     71.666667
# 7     68.333333
# 8     54.000000
# 9     47.666667
# 10    44.000000
# 11    42.666667
# 12    51.333333
# 13    57.666667
# 14    70.333333
# 15    73.666667
# 16    67.666667
# Name: Units Sold, dtype: float64
