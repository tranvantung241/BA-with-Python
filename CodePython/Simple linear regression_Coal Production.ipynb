# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cd C:\Users\QUYEN\Desktop\BA\Lap05
# Out:
# C:\Users\QUYEN\Desktop\BA\Lap05

# %%
pd.read_csv('Coal Production.csv')
# Out:
#     Year  Total Tons
# 0   1960   434329000
# 1   1961   420423000
# 2   1962   439043000
# 3   1963   477195000
# 4   1964   504182000
# 5   1965   526954000
# 6   1966   546822000
# 7   1967   564882000
# 8   1968   556706000
# 9   1969   570978000
# 10  1970   612661000
# 11  1971   560919000
# 12  1972   602492000
# 13  1973   598568000
# 14  1974   610023000
# 15  1975   654641000
# 16  1976   684913000
# 17  1977   697205000
# 18  1978   670164000
# 19  1979   781134000
# 20  1980   829700000
# 21  1981   823775000
# 22  1982   838112000
# 23  1983   782091000
# 24  1984   895920767
# 25  1985   883638117
# 26  1986   890314708
# 27  1987   918762162
# 28  1988   950265278
# 29  1989   980728790
# 30  1990  1029075527
# 31  1991   995983881
# 32  1992   997544933
# 33  1993   945424286
# 34  1994  1033504293
# 35  1995  1032973772
# 36  1996  1063855513
# 37  1997  1089931788
# 38  1998  1117535167
# 39  1999  1100431428
# 40  2000  1073611561
# 41  2001  1127688806
# 42  2002  1094283061
# 43  2003  1071752573
# 44  2004  1112098870
# 45  2005  1131498099
# 46  2006  1162749659
# 47  2007  1145567167

# %%
data=pd.read_csv('Coal Production.csv')
data.head()
# Out:
#    Year  Total Tons
# 0  1960   434329000
# 1  1961   420423000
# 2  1962   439043000
# 3  1963   477195000
# 4  1964   504182000

# %%
x = data['Year'].values
y = data['Total Tons'].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=3, random_state=0)

# %%
lm = LinearRegression()
x_train = x_train[:, None]
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print('intercept B0:',lm.intercept_)
print('Coff:',lm.coef_)
# Out:
# ('intercept B0:', -32202530629.924114)
# ('Coff:', array([16650480.0664798]))

# %%
sns.lmplot(x='Year', y='Total Tons', data=data)
