# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import scipy

import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols
# Out:
# C:\Users\TranTung\Anaconda3\envs\py27\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
 file = pd.read_excel(r"C:/Users/TranTung/Desktop/data/Insurance Survey1.xlsx", sheetname=0)
# Out:
# C:\Users\TranTung\Anaconda3\envs\py27\lib\site-packages\pandas\util\_decorators.py:118: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   return func(*args, **kwargs)

# %%
 file
# Out:
#     Age  Gender         Education Marital Status  Years Employed  \
# 0    36       2      Some college       Divorced               4
# 1    55       2      Some college       Divorced               2
# 2    61       1   Graduate degree        Widowed              26
# 3    65       2      Some college        Married               9
# 4    53       2   Graduate degree        Married               6
# 5    50       2   Graduate degree        Married              10
# 6    28       2  College graduate        Married               4
# 7    62       2  College graduate       Divorced               9
# 8    48       1   Graduate degree        Married               6
# 9    31       1   Graduate degree        Married               1
# 10   57       2  College graduate        Married               4
# 11   44       1  College graduate        Married               2
# 12   38       1      Some college        Married               3
# ...

# %%
 file.head()
# Out:
#    Age  Gender        Education Marital Status  Years Employed  Satisfaction  \
# 0   36       2     Some college       Divorced               4             4
# 1   55       2     Some college       Divorced               2             1
# 2   61       1  Graduate degree        Widowed              26             3
# 3   65       2     Some college        Married               9             4
# 4   53       2  Graduate degree        Married               6             4
#
#   Premium/Deductible
# 0                  N
# 1                  N
# 2                  N
# 3                  N
# 4                  N

# %%
file.describe()
# Out:
#              Age     Gender  Years Employed  Satisfaction
# count  24.000000  24.000000       24.000000     24.000000
# mean   45.041667   1.583333        8.000000      3.708333
# std    11.521168   0.503610        6.646346      1.122078
# min    27.000000   1.000000        1.000000      1.000000
# 25%    36.000000   1.000000        3.000000      3.000000
# 50%    45.500000   2.000000        5.500000      4.000000
# 75%    53.500000   2.000000       10.500000      5.000000
# max    65.000000   2.000000       26.000000      5.000000

# %%
cyl=file['Gender']
am=file['Satisfaction']

# %%
am
# Out:
# 0     4
# 1     1
# 2     3
# 3     4
# 4     4
# 5     5
# 6     5
# 7     3
# 8     5
# 9     5
# 10    5
# 11    3
# 12    2
# 13    3
# 14    4
# 15    3
# 16    3
# 17    3
# 18    5
# 19    4
# 20    4
# 21    5
# 22    4
# 23    2
# Name: Satisfaction, dtype: int64

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
# Age                   24 non-null int64
# Gender                24 non-null int64
# Education             24 non-null object
# Marital Status        24 non-null object
# Years Employed        24 non-null int64
# Satisfaction          24 non-null int64
# Premium/Deductible    24 non-null object
# dtypes: int64(4), object(3)
# memory usage: 1.4+ KB

# %%
import plotly.plotly as py
import plotly.graph_objs as go
from plotly.tools import FigureFactory as FF

# %%
from scipy import stats
stats.ttest_1samp(cyl, 2)
# Out:
# Ttest_1sampResult(statistic=-4.053217416888889, pvalue=0.0004928669214315254)

# %%
stats.f_oneway(cyl,am)
# Out:
# F_onewayResult(statistic=71.64431137724556, pvalue=6.173901926547453e-11)

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 7 columns):
# Age                   24 non-null int64
# Gender                24 non-null int64
# Education             24 non-null object
# Marital Status        24 non-null object
# Years Employed        24 non-null int64
# Satisfaction          24 non-null int64
# Premium/Deductible    24 non-null object
# dtypes: int64(4), object(3)
# memory usage: 1.4+ KB

# %%
file.columns
# Out:
# Index([u'Age', u'Gender', u'Education', u'Marital Status', u'Years Employed',
#        u'Satisfaction', u'Premium/Deductible'],
#       dtype='object')

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
 
cw =  pd.read_excel(r"C:/Users/TranTung/Desktop/data/Insurance Survey1.xlsx", sheetname=0)

cw_lm=ols('Gender ~ Satisfaction ', data=cw).fit() #Specify C for Categorical
print(sm.stats.anova_lm(cw_lm, typ=2))
# Out:
#                 sum_sq    df         F    PR(>F)
# Satisfaction  0.000240   1.0  0.000904  0.976279
# Residual      5.833094  22.0       NaN       NaN
